# %% [markdown]
# # **Step 1 - Loading up the libraries📚**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # **Step 2- Data Loading and Inspection Phase🔍**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Colab links /BBData.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# 3        Cleaning & Household      Bins & Bathroom Ware
# 4            Beauty & Hygiene          Bath & Hand Wash
# ...                       ...                       ...
# 27550        Beauty & Hygiene         Fragrances & Deos
# 27551    Gourmet & World Food    Cooking & Baking Needs
# 27552    Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553               Beverages                       Tea
# 27554        Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 0               Sri Sri Ayurveda       220.00         220.0
# 1                      Mastercook      180.00         180.0
# 2                             Trm      119.00         250.0
# 3                          Nakoda      149.00         176.0
# 4                           Nivea      162.00         162.0
# ...                           ...         ...           ...
# 27550                      Layerr      199.20         249.0
# 27551                    Puramate       67.50          75.0
# 27552                      FabBox      200.00         200.0
# 27553                      Tetley      396.00         495.0
# 27554  United Colors Of Benetton       214.53         390.0
#
#                            type  rating  \
# 0              Hair Oil & Serum     4.1
# 1        Water & Fridge Bottles     2.3
# 2               Lamp & Lamp Oil     3.4
# 3      Laundry, Storage Baskets     3.7
# 4          Bathing Bars & Soaps     4.4
# ...                         ...     ...
# 27550                   Perfume     3.9
# 27551  Herbs, Seasonings & Rubs     4.0
# 27552            Nachos & Chips     3.8
# 27553                  Tea Bags     4.2
# 27554          Men's Deodorants     4.5
#
#                                              description
# 0      This Product contains Garlic Oil that is known...
# 1      Each product is microwave safe (without lid), ...
# 2      A perfect gift for all occasions, be it your m...
# 3      Multipurpose container with an attractive desi...
# 4      Nivea Creme Soft Soap gives your skin the best...
# ...                                                  ...
# 27550  Layerr brings you Wottagirl Classic fragrant b...
# 27551  Puramate rosemary is enough to transform a dis...
# 27552  We have taken the richness of Sweet Potatoes (...
# 27553  Tetley Green Tea with its refreshing pure, ori...
# 27554  The new mens fragrance from the United Dreams ...
#
# [27555 rows x 10 columns]

# %% [markdown]
# ## **Data Inspection**

# %%
df.head().style.set_properties(
                                **{'background-color' : 'black',
                                 'color' : 'lightgreen',
                                 'border-color' : 'lightgreen',
                                    'border-style': 'solid'}

                       )
# Out:
# <style type="text/css">
# #T_b631f_row0_col0, #T_b631f_row0_col1, #T_b631f_row0_col2, #T_b631f_row0_col3, #T_b631f_row0_col4, #T_b631f_row0_col5, #T_b631f_row0_col6, #T_b631f_row0_col7, #T_b631f_row0_col8, #T_b631f_row0_col9, #T_b631f_row1_col0, #T_b631f_row1_col1, #T_b631f_row1_col2, #T_b631f_row1_col3, #T_b631f_row1_col4, #T_b631f_row1_col5, #T_b631f_row1_col6, #T_b631f_row1_col7, #T_b631f_row1_col8, #T_b631f_row1_col9, #T_b631f_row2_col0, #T_b631f_row2_col1, #T_b631f_row2_col2, #T_b631f_row2_col3, #T_b631f_row2_col4, #T_b631f_row2_col5, #T_b631f_row2_col6, #T_b631f_row2_col7, #T_b631f_row2_col8, #T_b631f_row2_col9, #T_b631f_row3_col0, #T_b631f_row3_col1, #T_b631f_row3_col2, #T_b631f_row3_col3, #T_b631f_row3_col4, #T_b631f_row3_col5, #T_b631f_row3_col6, #T_b631f_row3_col7, #T_b631f_row3_col8, #T_b631f_row3_col9, #T_b631f_row4_col0, #T_b631f_row4_col1, #T_b631f_row4_col2, #T_b631f_row4_col3, #T_b631f_row4_col4, #T_b631f_row4_col5, #T_b631f_row4_col6, #T_b631f_row4_col7, #T_b631f_row4_col8, #T_b631f_row4_col9 {
#   background-color: black;
#   color: lightgreen;
#   border-color: lightgreen;
#   border-style: solid;
# }
# </style>
# <table id="T_b631f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b631f_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_b631f_level0_col1" class="col_heading level0 col1" >product</th>
#       <th id="T_b631f_level0_col2" class="col_heading level0 col2" >category</th>
#       <th id="T_b631f_level0_col3" class="col_heading level0 col3" >sub_category</th>
#       <th id="T_b631f_level0_col4" class="col_heading level0 col4" >brand</th>
#       <th id="T_b631f_level0_col5" class="col_heading level0 col5" >sale_price</th>
#       <th id="T_b631f_level0_col6" class="col_heading level0 col6" >market_price</th>
#       <th id="T_b631f_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_b631f_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_b631f_level0_col9" class="col_heading level0 col9" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b631f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b631f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b631f_row0_col1" class="data row0 col1" >Garlic Oil - Vegetarian Capsule 500 mg</td>
#       <td id="T_b631f_row0_col2" class="data row0 col2" >Beauty & Hygiene</td>
#       <td id="T_b631f_row0_col3" class="data row0 col3" >Hair Care</td>
#       <td id="T_b631f_row0_col4" class="data row0 col4" >Sri Sri Ayurveda </td>
#       <td id="T_b631f_row0_col5" class="data row0 col5" >220.000000</td>
#       <td id="T_b631f_row0_col6" class="data row0 col6" >220.000000</td>
#       <td id="T_b631f_row0_col7" class="data row0 col7" >Hair Oil & Serum</td>
#       <td id="T_b631f_row0_col8" class="data row0 col8" >4.100000</td>
#       <td id="T_b631f_row0_col9" class="data row0 col9" >This Product contains Garlic Oil that is known to help proper digestion, maintain proper cholesterol levels, support cardiovascular and also build immunity.  For Beauty tips, tricks & more visit https://bigbasket.blog/</td>
#     </tr>
#     <tr>
#       <th id="T_b631f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b631f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_b631f_row1_col1" class="data row1 col1" >Water Bottle - Orange</td>
#       <td id="T_b631f_row1_col2" class="data row1 col2" >Kitchen, Garden & Pets</td>
#       <td id="T_b631f_row1_col3" class="data row1 col3" >Storage & Accessories</td>
#       <td id="T_b631f_row1_col4" class="data row1 col4" >Mastercook</td>
#       <td id="T_b631f_row1_col5" class="data row1 col5" >180.000000</td>
#       <td id="T_b631f_row1_col6" class="data row1 col6" >180.000000</td>
#       <td id="T_b631f_row1_col7" class="data row1 col7" >Water & Fridge Bottles</td>
#       <td id="T_b631f_row1_col8" class="data row1 col8" >2.300000</td>
#       <td id="T_b631f_row1_col9" class="data row1 col9" >Each product is microwave safe (without lid), refrigerator safe, dishwasher safe and can also be used for re-heating food and not for cooking. All containers come with airtight lids and a wide variety of attractive colours. Stack these stylish and colourful containers in your kitchen with ease and for a look-good factor.</td>
#     </tr>
#     <tr>
#       <th id="T_b631f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b631f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_b631f_row2_col1" class="data row2 col1" >Brass Angle Deep - Plain, No.2</td>
#       <td id="T_b631f_row2_col2" class="data row2 col2" >Cleaning & Household</td>
#       <td id="T_b631f_row2_col3" class="data row2 col3" >Pooja Needs</td>
#       <td id="T_b631f_row2_col4" class="data row2 col4" >Trm</td>
#       <td id="T_b631f_row2_col5" class="data row2 col5" >119.000000</td>
#       <td id="T_b631f_row2_col6" class="data row2 col6" >250.000000</td>
#       <td id="T_b631f_row2_col7" class="data row2 col7" >Lamp & Lamp Oil</td>
#       <td id="T_b631f_row2_col8" class="data row2 col8" >3.400000</td>
#       <td id="T_b631f_row2_col9" class="data row2 col9" >A perfect gift for all occasions, be it your mother, sister, in-laws, boss or your friends, this beautiful designer piece wherever placed, is sure to beautify the surroundings Traditional design This type diya has been used for Diwali and All other Festivals for centuries. Sturdy and easy to carry The feet keep it balanced to ensure safety. Wonderful Oil Lamp made in Brass also called as Jyoti. This is a handcrafted piece of Indian brass Deepak.</td>
#     </tr>
#     <tr>
#       <th id="T_b631f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b631f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_b631f_row3_col1" class="data row3 col1" >Cereal Flip Lid Container/Storage Jar - Assorted Colour</td>
#       <td id="T_b631f_row3_col2" class="data row3 col2" >Cleaning & Household</td>
#       <td id="T_b631f_row3_col3" class="data row3 col3" >Bins & Bathroom Ware</td>
#       <td id="T_b631f_row3_col4" class="data row3 col4" >Nakoda</td>
#       <td id="T_b631f_row3_col5" class="data row3 col5" >149.000000</td>
#       <td id="T_b631f_row3_col6" class="data row3 col6" >176.000000</td>
#       <td id="T_b631f_row3_col7" class="data row3 col7" >Laundry, Storage Baskets</td>
#       <td id="T_b631f_row3_col8" class="data row3 col8" >3.700000</td>
#       <td id="T_b631f_row3_col9" class="data row3 col9" >Multipurpose container with an attractive design and made from food-grade plastic for your hygiene and safety ideal for storing pulses. Grains, spices, and more with easy opening and closing flip-open lid. Strong, durable and transparent body for longevity and easy identification of contents. Multipurpose storage solution for your daily needs stores your everyday food essentials in style with the Nakoda container set. With transparent bodies, you can easily identify your stored items without having to open the lids. These containers are ideal for storing a large variety of items such as food grains, snacks and pulses to sugar, spices, condiments and more. Featuring unique flip-open lids, you can easily open and close this container without any hassles.
# The Nakoda container is made from high-quality food-grade and BPA-free plastic that is 100% safe for storing food items. You can safely store your food items in this container without worrying about contamination and harmful toxins. As they are constructed using highly durable virgin plastic, this container will last for a long time even with regular use. This container can enhance the overall look of your kitchen decor. Being dishwasher safe, cleaning and maintaining this container is an easy task. You can also use a simple soap solution to manually wash and retain their looks for a long time.</td>
#     </tr>
#     <tr>
#       <th id="T_b631f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b631f_row4_col0" class="data row4 col0" >5</td>

# %% [markdown]
# ## **Shape Inspection**

# %%
a = df.shape
print(f'Rows: {a[0]} and columns: {a[1]}')
# Out:
# Rows: 27555 and columns: 10

# %% [markdown]
# ##**Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# # **Step 3 - Data Preprocessing**

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %% [markdown]
# ## **Working with the product**

# %%
df['product'] = df['product'].fillna('NO_PRODUCT_NAME')

# %% [markdown]
# ##**Work with brand**

# %%
df['brand'].value_counts()
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Sanitt                1
# Fazlani               1
# Fakira                1
# Sofia                 1
# Tez                   1
# Name: count, Length: 2313, dtype: int64

# %%
df['brand'].mode()[0]
# Out:
# 'Fresho'

# %%
df['brand'] = df['brand'].fillna(df['brand'].mode()[0])

# %%
df.isnull().sum()
# Out:
# index              0
# product            0
# category           0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# index            0.000000
# product          0.000000
# category         0.000000
# sub_category     0.000000
# brand            0.000000
# sale_price       0.000000
# market_price     0.000000
# type             0.000000
# rating          31.304663
# description      0.000000
# dtype: float64

# %% [markdown]
# ###**Work with description**

# %%
df.description = df['description'].fillna('UNKNOWN_DESCRIPTION')

# %%
sns.displot(df['rating'])

# %%
df["rating"].mean(), df["rating"].median()
# Out:
# (np.float64(3.943409583179249), 4.1)

# %%
df['rating'] = df['rating'].fillna(df['rating'].mean())

# %%
sns.displot(df['rating'])

# %%
df.isnull().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# 3        Cleaning & Household      Bins & Bathroom Ware
# 4            Beauty & Hygiene          Bath & Hand Wash
# ...                       ...                       ...
# 27550        Beauty & Hygiene         Fragrances & Deos
# 27551    Gourmet & World Food    Cooking & Baking Needs
# 27552    Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553               Beverages                       Tea
# 27554        Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 0               Sri Sri Ayurveda       220.00         220.0
# 1                      Mastercook      180.00         180.0
# 2                             Trm      119.00         250.0
# 3                          Nakoda      149.00         176.0
# 4                           Nivea      162.00         162.0
# ...                           ...         ...           ...
# 27550                      Layerr      199.20         249.0
# 27551                    Puramate       67.50          75.0
# 27552                      FabBox      200.00         200.0
# 27553                      Tetley      396.00         495.0
# 27554  United Colors Of Benetton       214.53         390.0
#
#                            type  rating  \
# 0              Hair Oil & Serum     4.1
# 1        Water & Fridge Bottles     2.3
# 2               Lamp & Lamp Oil     3.4
# 3      Laundry, Storage Baskets     3.7
# 4          Bathing Bars & Soaps     4.4
# ...                         ...     ...
# 27550                   Perfume     3.9
# 27551  Herbs, Seasonings & Rubs     4.0
# 27552            Nachos & Chips     3.8
# 27553                  Tea Bags     4.2
# 27554          Men's Deodorants     4.5
#
#                                              description
# 0      This Product contains Garlic Oil that is known...
# 1      Each product is microwave safe (without lid), ...
# 2      A perfect gift for all occasions, be it your m...
# 3      Multipurpose container with an attractive desi...
# 4      Nivea Creme Soft Soap gives your skin the best...
# ...                                                  ...
# 27550  Layerr brings you Wottagirl Classic fragrant b...
# 27551  Puramate rosemary is enough to transform a dis...
# 27552  We have taken the richness of Sweet Potatoes (...
# 27553  Tetley Green Tea with its refreshing pure, ori...
# 27554  The new mens fragrance from the United Dreams ...
#
# [27555 rows x 10 columns]

# %% [markdown]
# ##**Round off the numerical values for prices**

# %%
df['sale_price'] = df['sale_price'].round().astype('int64')

# %%
df['market_price'] = df['market_price'].round().astype('int64')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# 3        Cleaning & Household      Bins & Bathroom Ware
# 4            Beauty & Hygiene          Bath & Hand Wash
# ...                       ...                       ...
# 27550        Beauty & Hygiene         Fragrances & Deos
# 27551    Gourmet & World Food    Cooking & Baking Needs
# 27552    Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553               Beverages                       Tea
# 27554        Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 0               Sri Sri Ayurveda          220           220
# 1                      Mastercook         180           180
# 2                             Trm         119           250
# 3                          Nakoda         149           176
# 4                           Nivea         162           162
# ...                           ...         ...           ...
# 27550                      Layerr         199           249
# 27551                    Puramate          68            75
# 27552                      FabBox         200           200
# 27553                      Tetley         396           495
# 27554  United Colors Of Benetton          215           390
#
#                            type  rating  \
# 0              Hair Oil & Serum     4.1
# 1        Water & Fridge Bottles     2.3
# 2               Lamp & Lamp Oil     3.4
# 3      Laundry, Storage Baskets     3.7
# 4          Bathing Bars & Soaps     4.4
# ...                         ...     ...
# 27550                   Perfume     3.9
# 27551  Herbs, Seasonings & Rubs     4.0
# 27552            Nachos & Chips     3.8
# 27553                  Tea Bags     4.2
# 27554          Men's Deodorants     4.5
#
#                                              description
# 0      This Product contains Garlic Oil that is known...
# 1      Each product is microwave safe (without lid), ...
# 2      A perfect gift for all occasions, be it your m...
# 3      Multipurpose container with an attractive desi...
# 4      Nivea Creme Soft Soap gives your skin the best...
# ...                                                  ...
# 27550  Layerr brings you Wottagirl Classic fragrant b...
# 27551  Puramate rosemary is enough to transform a dis...
# 27552  We have taken the richness of Sweet Potatoes (...
# 27553  Tetley Green Tea with its refreshing pure, ori...
# 27554  The new mens fragrance from the United Dreams ...
#
# [27555 rows x 10 columns]

# %% [markdown]
# #**Step 4 - Exploratory Data Analysis 🌐🫨**

# %% [markdown]
# Objective 1 - Finding out the discounts available on items

# %%
df['discounts'] = (((df['market_price'] - df['sale_price']) / df['market_price'])*100)

# %%
df['discounts'].head()
# Out:
# 0     0.000000
# 1     0.000000
# 2    52.400000
# 3    15.340909
# 4     0.000000
# Name: discounts, dtype: float64

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# 3        Cleaning & Household      Bins & Bathroom Ware
# 4            Beauty & Hygiene          Bath & Hand Wash
# ...                       ...                       ...
# 27550        Beauty & Hygiene         Fragrances & Deos
# 27551    Gourmet & World Food    Cooking & Baking Needs
# 27552    Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553               Beverages                       Tea
# 27554        Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 0               Sri Sri Ayurveda          220           220
# 1                      Mastercook         180           180
# 2                             Trm         119           250
# 3                          Nakoda         149           176
# 4                           Nivea         162           162
# ...                           ...         ...           ...
# 27550                      Layerr         199           249
# 27551                    Puramate          68            75
# 27552                      FabBox         200           200
# 27553                      Tetley         396           495
# 27554  United Colors Of Benetton          215           390
#
#                            type  rating  \
# 0              Hair Oil & Serum     4.1
# 1        Water & Fridge Bottles     2.3
# 2               Lamp & Lamp Oil     3.4
# 3      Laundry, Storage Baskets     3.7
# 4          Bathing Bars & Soaps     4.4
# ...                         ...     ...
# 27550                   Perfume     3.9
# 27551  Herbs, Seasonings & Rubs     4.0
# 27552            Nachos & Chips     3.8
# 27553                  Tea Bags     4.2
# 27554          Men's Deodorants     4.5
#
#                                              description  discounts
# 0      This Product contains Garlic Oil that is known...   0.000000
# 1      Each product is microwave safe (without lid), ...   0.000000
# 2      A perfect gift for all occasions, be it your m...  52.400000
# 3      Multipurpose container with an attractive desi...  15.340909
# 4      Nivea Creme Soft Soap gives your skin the best...   0.000000
# ...                                                  ...        ...
# 27550  Layerr brings you Wottagirl Classic fragrant b...  20.080321
# 27551  Puramate rosemary is enough to transform a dis...   9.333333
# 27552  We have taken the richness of Sweet Potatoes (...   0.000000
# 27553  Tetley Green Tea with its refreshing pure, ori...  20.000000
# 27554  The new mens fragrance from the United Dreams ...  44.871795
#
# [27555 rows x 11 columns]

# %% [markdown]
# **Objective 2 - Find out the particular product or category that relates to the highest discounts**

# %%
df[['product','category','market_price','sale_price','discounts']].sort_values('discounts',ascending=False).head(15).style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_9d9cb_row0_col2, #T_9d9cb_row0_col3, #T_9d9cb_row14_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9d9cb_row0_col4, #T_9d9cb_row14_col2, #T_9d9cb_row14_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9d9cb_row1_col2, #T_9d9cb_row6_col2, #T_9d9cb_row7_col2 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_9d9cb_row1_col3, #T_9d9cb_row5_col3 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_9d9cb_row1_col4 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_9d9cb_row2_col2, #T_9d9cb_row8_col2 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_9d9cb_row2_col3 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_9d9cb_row2_col4 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_9d9cb_row3_col2 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_9d9cb_row3_col3 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_9d9cb_row3_col4 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_9d9cb_row4_col2 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_9d9cb_row4_col3 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_9d9cb_row4_col4 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_9d9cb_row5_col2 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_9d9cb_row5_col4 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_9d9cb_row6_col3, #T_9d9cb_row7_col3 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_9d9cb_row6_col4, #T_9d9cb_row7_col4 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_9d9cb_row8_col3 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_9d9cb_row8_col4 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_9d9cb_row9_col2, #T_9d9cb_row10_col2, #T_9d9cb_row11_col2, #T_9d9cb_row12_col2 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_9d9cb_row9_col3, #T_9d9cb_row10_col3 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_9d9cb_row9_col4, #T_9d9cb_row10_col4 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_9d9cb_row11_col3, #T_9d9cb_row12_col3 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_9d9cb_row11_col4, #T_9d9cb_row12_col4 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_9d9cb_row13_col2, #T_9d9cb_row13_col3 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_9d9cb_row13_col4 {
#   background-color: #f1faee;
#   color: #000000;
# }
# </style>
# <table id="T_9d9cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d9cb_level0_col0" class="col_heading level0 col0" >product</th>
#       <th id="T_9d9cb_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_9d9cb_level0_col2" class="col_heading level0 col2" >market_price</th>
#       <th id="T_9d9cb_level0_col3" class="col_heading level0 col3" >sale_price</th>
#       <th id="T_9d9cb_level0_col4" class="col_heading level0 col4" >discounts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d9cb_level0_row0" class="row_heading level0 row0" >26976</th>
#       <td id="T_9d9cb_row0_col0" class="data row0 col0" >Curry Leaves</td>
#       <td id="T_9d9cb_row0_col1" class="data row0 col1" >Fruits & Vegetables</td>
#       <td id="T_9d9cb_row0_col2" class="data row0 col2" >15</td>
#       <td id="T_9d9cb_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_9d9cb_row0_col4" class="data row0 col4" >86.666667</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row1" class="row_heading level0 row1" >17713</th>
#       <td id="T_9d9cb_row1_col0" class="data row1 col0" >Fruit & Vegetables Hand Juicer</td>
#       <td id="T_9d9cb_row1_col1" class="data row1 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row1_col2" class="data row1 col2" >1995</td>
#       <td id="T_9d9cb_row1_col3" class="data row1 col3" >349</td>
#       <td id="T_9d9cb_row1_col4" class="data row1 col4" >82.506266</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row2" class="row_heading level0 row2" >13318</th>
#       <td id="T_9d9cb_row2_col0" class="data row2 col0" >Small Silicone Spatula With Plastic Handle - Assorted Colours</td>
#       <td id="T_9d9cb_row2_col1" class="data row2 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row2_col2" class="data row2 col2" >399</td>
#       <td id="T_9d9cb_row2_col3" class="data row2 col3" >75</td>
#       <td id="T_9d9cb_row2_col4" class="data row2 col4" >81.203008</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row3" class="row_heading level0 row3" >13740</th>
#       <td id="T_9d9cb_row3_col0" class="data row3 col0" >Decorative Party Light Big Star String LED Light 2 M - Multicolour</td>
#       <td id="T_9d9cb_row3_col1" class="data row3 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row3_col2" class="data row3 col2" >1099</td>
#       <td id="T_9d9cb_row3_col3" class="data row3 col3" >209</td>
#       <td id="T_9d9cb_row3_col4" class="data row3 col4" >80.982712</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row4" class="row_heading level0 row4" >10438</th>
#       <td id="T_9d9cb_row4_col0" class="data row4 col0" >NHS 860 Temperature Control Professional Hair Straightener</td>
#       <td id="T_9d9cb_row4_col1" class="data row4 col1" >Beauty & Hygiene</td>
#       <td id="T_9d9cb_row4_col2" class="data row4 col2" >2395</td>
#       <td id="T_9d9cb_row4_col3" class="data row4 col3" >467</td>
#       <td id="T_9d9cb_row4_col4" class="data row4 col4" >80.501044</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row5" class="row_heading level0 row5" >4562</th>
#       <td id="T_9d9cb_row5_col0" class="data row5 col0" >Concealer Brush 930</td>
#       <td id="T_9d9cb_row5_col1" class="data row5 col1" >Beauty & Hygiene</td>
#       <td id="T_9d9cb_row5_col2" class="data row5 col2" >1750</td>
#       <td id="T_9d9cb_row5_col3" class="data row5 col3" >350</td>
#       <td id="T_9d9cb_row5_col4" class="data row5 col4" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row6" class="row_heading level0 row6" >11473</th>
#       <td id="T_9d9cb_row6_col0" class="data row6 col0" >Decorative Party Light Golden Bell String LED Light 7 M - Warm White</td>
#       <td id="T_9d9cb_row6_col1" class="data row6 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row6_col2" class="data row6 col2" >1999</td>
#       <td id="T_9d9cb_row6_col3" class="data row6 col3" >415</td>
#       <td id="T_9d9cb_row6_col4" class="data row6 col4" >79.239620</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row7" class="row_heading level0 row7" >13265</th>
#       <td id="T_9d9cb_row7_col0" class="data row7 col0" >Decorative Party Light Golden Bell String LED Light 7 M - Multicolour</td>
#       <td id="T_9d9cb_row7_col1" class="data row7 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row7_col2" class="data row7 col2" >1999</td>
#       <td id="T_9d9cb_row7_col3" class="data row7 col3" >415</td>
#       <td id="T_9d9cb_row7_col4" class="data row7 col4" >79.239620</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row8" class="row_heading level0 row8" >10092</th>
#       <td id="T_9d9cb_row8_col0" class="data row8 col0" >USB String Fairy Lights 3M 30 LED For Decoration - Multicolour</td>
#       <td id="T_9d9cb_row8_col1" class="data row8 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row8_col2" class="data row8 col2" >399</td>
#       <td id="T_9d9cb_row8_col3" class="data row8 col3" >85</td>
#       <td id="T_9d9cb_row8_col4" class="data row8 col4" >78.696742</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row9" class="row_heading level0 row9" >398</th>
#       <td id="T_9d9cb_row9_col0" class="data row9 col0" >Steel Belly Shape Storage Dabba/ Container Set With PP Lid - Silver & Blue</td>
#       <td id="T_9d9cb_row9_col1" class="data row9 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_9d9cb_row9_col2" class="data row9 col2" >995</td>
#       <td id="T_9d9cb_row9_col3" class="data row9 col3" >219</td>
#       <td id="T_9d9cb_row9_col4" class="data row9 col4" >77.989950</td>
#     </tr>
#     <tr>
#       <th id="T_9d9cb_level0_row10" class="row_heading level0 row10" >24292</th>
#       <td id="T_9d9cb_row10_col0" class="data row10 col0" >St

# %%
df[['product','category','discounts']][df['discounts'] == df['discounts'].max()]
# Out:
#             product             category  discounts
# 26976  Curry Leaves  Fruits & Vegetables  86.666667

# %% [markdown]
# **Average discount for any perticular category**

# %%
df[df['category'] == 'Fruits & Vegetables']['discounts'].mean()
# Out:
# np.float64(21.266544727722216)

# %%
df.groupby(['category'])['discounts'].mean().sort_values(ascending=False)
# Out:
# category
# Kitchen, Garden & Pets      22.174895
# Fruits & Vegetables         21.266545
# Beauty & Hygiene            12.354489
# Foodgrains, Oil & Masala    11.847165
# Cleaning & Household        10.795026
# Beverages                    9.564089
# Eggs, Meat & Fish            8.064908
# Gourmet & World Food         7.869536
# Bakery, Cakes & Dairy        7.684198
# Snacks & Branded Foods       6.642546
# Baby Care                    5.856489
# Name: discounts, dtype: float64

# %% [markdown]
# ###**Objective 3 - Analysing the data on the basis on demands that is Products & Categories**

# %%
catProd_data = df[['category','product']]

catProd_data = catProd_data.drop_duplicates()

catProd_data = catProd_data.groupby('category').agg(product_count = ('product','count')).reset_index().sort_values('product_count', ascending=False)

# %%
catProd_data.head()
# Out:
#                   category  product_count
# 2         Beauty & Hygiene           6839
# 8     Gourmet & World Food           4109
# 9   Kitchen, Garden & Pets           3186
# 10  Snacks & Branded Foods           2454
# 4     Cleaning & Household           2411

# %%
fig = px.bar(catProd_data,x = 'category', y ='product_count', color='category', title = 'Analysis on the basis of Category and Product Count' )
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2529a83-321a-4fa9-8f5d-126aea3dfdad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2529a83-321a-4fa9-8f5d-126aea3dfdad")) {                    Plotly.newPlot(                        "c2529a83-321a-4fa9-8f5d-126aea3dfdad",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beauty & Hygiene","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Beauty & Hygiene","offsetgroup":"Beauty & Hygiene","orientation":"v","showlegend":true,"textposition":"auto","x":["Beauty & Hygiene"],"xaxis":"x","y":[6839],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gourmet & World Food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Gourmet & World Food","offsetgroup":"Gourmet & World Food","orientation":"v","showlegend":true,"textposition":"auto","x":["Gourmet & World Food"],"xaxis":"x","y":[4109],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kitchen, Garden & Pets","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Kitchen, Garden & Pets","offsetgroup":"Kitchen, Garden & Pets","orientation":"v","showlegend":true,"textposition":"auto","x":["Kitchen, Garden & Pets"],"xaxis":"x","y":[3186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snacks & Branded Foods","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Snacks & Branded Foods","offsetgroup":"Snacks & Branded Foods","orientation":"v","showlegend":true,"textposition":"auto","x":["Snacks & Branded Foods"],"xaxis":"x","y":[2454],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cleaning & Household","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cleaning & Household","offsetgroup":"Cleaning & Household","orientation":"v","showlegend":true,"textposition":"auto","x":["Cleaning & Household"],"xaxis":"x","y":[2411],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foodgrains, Oil & Masala","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Foodgrains, Oil & Masala","offsetgroup":"Foodgrains, Oil & Masala","orientation":"v","showlegend":true,"textposition":"auto","x":["Foodgrains, Oil & Masala"],"xaxis":"x","y":[1997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Beverages","offsetgroup":"Beverages","orientation":"v","showlegend":true,"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[756],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bakery, Cakes & Dairy","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Bakery, Cakes & Dairy","offsetgroup":"Bakery, Cakes & Dairy","orientation":"v","showlegend":true,"textposition":"auto","x":["Bakery, Cakes & Dairy"],"xaxis":"x","y":[752],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003ce ...

# %% [markdown]
# **Objective 4 - Analysis on the basis of Brand and Type, to know which are the brands that are famous among consumer and what kind of products are famous from those brands.**

# %%
brandType_data = df[['brand','type']]

brandType_data = brandType_data.drop_duplicates()

brandType_data = brandType_data.groupby('brand').agg(type_count = ('type','count')).reset_index().sort_values('type_count',ascending=False)

# %%
brandType_data
# Out:
#               brand  type_count
# 2295       bb Combo          53
# 741          Fresho          42
# 171         BB Home          37
# 507           Dabur          34
# 2297       bb Royal          32
# ...             ...         ...
# 2253          X-MEN           1
# 2252       Wrigleys           1
# 2250   Wow Confetti           1
# 2249  Wow Chocolina           1
# 2280           Zago           1
#
# [2313 rows x 2 columns]

# %%
fig = px.bar(brandType_data.head(10), x = 'brand', y = 'type_count', color = 'brand', title = 'Analysis on the basis of Brand and Type and Type Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="258310a9-7edb-40cf-adc8-7041ea8eb59d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("258310a9-7edb-40cf-adc8-7041ea8eb59d")) {                    Plotly.newPlot(                        "258310a9-7edb-40cf-adc8-7041ea8eb59d",                        [{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bb Combo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bb Combo","offsetgroup":"bb Combo","orientation":"v","showlegend":true,"textposition":"auto","x":["bb Combo"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fresho","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Fresho","offsetgroup":"Fresho","orientation":"v","showlegend":true,"textposition":"auto","x":["Fresho"],"xaxis":"x","y":[42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BB Home","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BB Home","offsetgroup":"BB Home","orientation":"v","showlegend":true,"textposition":"auto","x":["BB Home"],"xaxis":"x","y":[37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dabur","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Dabur","offsetgroup":"Dabur","orientation":"v","showlegend":true,"textposition":"auto","x":["Dabur"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bb Royal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"bb Royal","offsetgroup":"bb Royal","orientation":"v","showlegend":true,"textposition":"auto","x":["bb Royal"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DP","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"DP","offsetgroup":"DP","orientation":"v","showlegend":true,"textposition":"auto","x":["DP"],"xaxis":"x","y":[31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nutty Yogi","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Nutty Yogi","offsetgroup":"Nutty Yogi","orientation":"v","showlegend":true,"textposition":"auto","x":["Nutty Yogi"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NUTRIWISH","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"NUTRIWISH","offsetgroup":"NUTRIWISH","orientation":"v","showlegend":true,"textposition":"auto","x":["NUTRIWISH"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patanjali","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Patanjali","offsetgroup":"Patanjali","orientation":"v","showlegend":true,"textposition":"auto","x":["Patanjali"],"xaxis":"x","y":[21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Urban Platter","marker":{"color":"#FECB52","p ...

# %% [markdown]
# ###**Price Analysis**

# %%
print(f"Analysis on Sales price")
print("Mean: ", df["sale_price"].mean())
print("Maximum Pricing: ", df["sale_price"].max())
print("Minimum Pricing: ", df["sale_price"].min())
# Out:
# Analysis on Sales price
# Mean:  322.5060424605335
# Maximum Pricing:  12500
# Minimum Pricing:  2

# %% [markdown]
# ###**Defining the ranges**

# %%
range_val = [
    ['1-10',1, 10],
 ['11-25', 11, 25],
  ['26-50', 26, 50],
   ['51-100',51, 100],
    ['101-150', 101, 150],
     ['151-200', 151, 200],
      ['201-300',201, 300],
       ['301-400', 301, 400],
        ['401-500', 401, 500],
         ['501-1000',501, 1000],
          ['1001-1500', 1001, 1500],
           ['1501-2000', 1501, 2000],
              ['2001-3000',2001, 3000],
               ['3001-5000', 3001, 5000],
                ['5001-10000', 5001, 10000],
                 ['10001-15000',10001, 15000]]

# %%
range_data = pd.DataFrame(range_val, columns = ['range_name','min_value','max_value'])

range_data
# Out:
#      range_name  min_value  max_value
# 0          1-10          1         10
# 1         11-25         11         25
# 2         26-50         26         50
# 3        51-100         51        100
# 4       101-150        101        150
# 5       151-200        151        200
# 6       201-300        201        300
# 7       301-400        301        400
# 8       401-500        401        500
# 9      501-1000        501       1000
# 10    1001-1500       1001       1500
# 11    1501-2000       1501       2000
# 12    2001-3000       2001       3000
# 13    3001-5000       3001       5000
# 14   5001-10000       5001      10000
# 15  10001-15000      10001      15000

# %%
range_data['product_count'] = ''

# %%
for idx, rows in range_data.iterrows():


  range_data.at[idx, "product_count"] = len(df["product"][(df["sale_price"] >= rows["min_value"]) & (df["sale_price"] <= rows["max_value"])])

# %%
range_data
# Out:
#      range_name  min_value  max_value product_count
# 0          1-10          1         10           178
# 1         11-25         11         25           689
# 2         26-50         26         50          2232
# 3        51-100         51        100          4654
# 4       101-150        101        150          3661
# 5       151-200        151        200          3196
# 6       201-300        201        300          4568
# 7       301-400        301        400          2555
# 8       401-500        401        500          1693
# 9      501-1000        501       1000          2773
# 10    1001-1500       1001       1500           666
# 11    1501-2000       1501       2000           300
# 12    2001-3000       2001       3000           222
# 13    3001-5000       3001       5000           122
# 14   5001-10000       5001      10000            44
# 15  10001-15000      10001      15000             2

# %%
fig = px.bar(range_data, x = "range_name", y = "product_count", color = "range_name", title = "Price Analysis")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="29f6b8b6-c695-43f2-983b-f1bfbfe564b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29f6b8b6-c695-43f2-983b-f1bfbfe564b7")) {                    Plotly.newPlot(                        "29f6b8b6-c695-43f2-983b-f1bfbfe564b7",                        [{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-10","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1-10","offsetgroup":"1-10","orientation":"v","showlegend":true,"textposition":"auto","x":["1-10"],"xaxis":"x","y":[178],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11-25","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"11-25","offsetgroup":"11-25","orientation":"v","showlegend":true,"textposition":"auto","x":["11-25"],"xaxis":"x","y":[689],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"26-50","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"26-50","offsetgroup":"26-50","orientation":"v","showlegend":true,"textposition":"auto","x":["26-50"],"xaxis":"x","y":[2232],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"51-100","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"51-100","offsetgroup":"51-100","orientation":"v","showlegend":true,"textposition":"auto","x":["51-100"],"xaxis":"x","y":[4654],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"101-150","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"101-150","offsetgroup":"101-150","orientation":"v","showlegend":true,"textposition":"auto","x":["101-150"],"xaxis":"x","y":[3661],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"151-200","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"151-200","offsetgroup":"151-200","orientation":"v","showlegend":true,"textposition":"auto","x":["151-200"],"xaxis":"x","y":[3196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"201-300","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"201-300","offsetgroup":"201-300","orientation":"v","showlegend":true,"textposition":"auto","x":["201-300"],"xaxis":"x","y":[4568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"301-400","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"301-400","offsetgroup":"301-400","orientation":"v","showlegend":true,"textposition":"auto","x":["301-400"],"xaxis":"x","y":[2555],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"401-500","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"401-500","offsetgroup":"401-500","orientation":"v","showlegend":true,"textposition":"auto","x":["401-500"],"xaxis":"x","y":[1693],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e", ...

# %% [markdown]
# # **Thank you**
